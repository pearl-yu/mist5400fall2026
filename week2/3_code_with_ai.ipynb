# %% [markdown]
# <a href="https://colab.research.google.com/github/pearl-yu/mist5400fall2026/blob/main/week2/3_code_with_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code with AI
#
#
# MIST5400 Fall 2026 - Instructor: Pearl (Peiyan) Yu
#
# ***

# %% [markdown]
# After you completed this notebook, **download the notebook as a ipynb file and submit in eLC assignment --> In-class exercise 1.**

# %% [markdown]
# We will start by analyzing a dataset of college enrollments. Please use this link to download the dataset to your laptop: [Download the dataset](https://drive.google.com/uc?export=download&id=1S80F6kmmSnbk94FcEPPHzKuzA-NLk6hp)
#
# Then upload the local dataset (the College_Data.csv downloaded to your laptop earlier) to our current workspace: Click on the folder icon on the left-side bar, use the upload button or drag the dataset in.
#
# <img src="https://drive.google.com/uc?id=1ITSANaV_7nCA4UCG0BIPZdxDANkO_MV6" width="300">
#
#
# Or, we could open the Gemini side panel, and upload the data use the '+' button:
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It contains a number of variables for 777 different universities and colleges in the US. The variables are:
#
# - Private : Public/private indicator
# - Apps : Number of applications received
# - Accept : Number of applicants accepted
# - Enroll : Number of new students enrolled
# - Top10perc : New students from top 10 % of high school class
# - Top25perc : New students from top 25 % of high school class
# - F. Undergrad : Number of full-time undergraduates
# - P.Undergrad : Number of part-time undergraduates
# - Outstate : Out-of-state tuition
# - Room.Board : Room and board costs
# - Books : Estimated book costs
# - Personal : Estimated personal spending
# - PhD : Percent of faculty with Ph.D.s
# - Terminal : Percent of faculty with terminal degree
# - S.F.Ratio : Student/faculty ratio
# - perc.alumni : Percent of alumni who donate
# - Expend : Instructional expenditure per student
# - Grad.Rate : Graduation rate

# %% [markdown]
# Gemini: It's integrated into Colab. Free to use. You can also get the p[ro version](https://gemini.google/students/?utm_source=gemini&utm_medium=paid_media&utm_campaign=microsite_sem_students-sem-microsite-bkws_generic_generic_text&gclsrc=aw.ds&gad_source=1&gad_campaignid=24113101888&gbraid=0AAAAAC_C9PR6z6HgVqzzP2TS7z-Vnyhcc&gclid=CjwKCAjwwL_UBhAjEiwAEhuT5O82msHvt_QHe-XsFR2x1_dokgf0Ll4_qybQ5xxymkZBx_VyiKlAiBoCR1UQAvD_BwE) which is free for students for 1 year.
#
# Can type **at the hashtag** in a code cell.  Or, use the **generate** function.

# %% [markdown]
# ## Explain code
#
# We could, ask your GenAI model to explain the code / add comments: Select a cell
#
# ![image.png](data:image/png;base64,...)
#
# Select a cell, and click on the magic pen icon in the menu bar on the upper-right corner

# %%
# prompt: Can you add comments to explain what the packages are for?
# start by importing packages

import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Generate code for easy things
#
# This is recommended for easy things that you know how to do, but just want to save time.
#
#
# To put/edit content into a specific cell:
# - Select a code cell, click on the magic pen button and click on 'Generate code' or 'Transform code';
#
# To generat multiple cells of code:
# - Click on the Gemini icon at the end of the page.

# %% [markdown]
# Now let's ask Gemini to import this dataset in our Cloud workspace. You could use this prompt: import the College_Data.cvs

# %% [markdown]
# Now we'd like to preview what the data looks like.
#
# Prompt: Display the first few rows of the dataframe to verify

# %% [markdown]
# ## Debug
#
# We can also ask it to debug code, find errors and correct them.

# %%
# Prompt: debug?
collage.descibe()

# %% [markdown]
# ## Generate code for more stuff

# %%
# example prompt: change the column name from Unamed:0 to SchoolName

# %%
# example prompt: plot a histogram of Top10Perc

# %%
# example prompt: find the top 10 schools with the best Graduation Rates

# %% [markdown]
# After you completed this notebook, remember to **download the notebook as a ipynb file and submit in eLC assignment --> In-class exercise 1.**

# %% [markdown]
# ***[The End]***
